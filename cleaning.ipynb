# %%
import pandas as pd
import json

# Load raw JSON
with open("faculty_raw.json", "r", encoding="utf-8") as f:
    data = json.load(f)

df = pd.DataFrame(data)

print("Initial shape:", df.shape)
df.head()
# Out:
# Initial shape: (109, 7)
#   faculty_type             name  \
# 0      regular   Abhishek gupta
# 1      regular  Abhishek jindal
# 2      regular   Abhishek tilva
# 3      regular      Aditya tatu
# 4      regular     Ajay beniwal
#
#                                            education         phone  \
# 0  PhD (Electrical and Computer Engineering), Tor...  079-68261598
# 1  PhD (Electronics & Communication Engineering),...  079-68261654
# 2  PhD (Statistics), Columbia University, New Yor...  079-68261549
# 3  PhD (Computer Science), University of Copenhag...  079-68261540
# 4  PhD (Electronics and Communication Engineering...  079-68261745
#
#                                              address  \
# 0  # 3208, FB-3, DAU, Gandhinagar, Gujarat, India...
# 1  # 4101, FB-4, DA-IICT, Gandhinagar, Gujarat, I...
# 2  # 2209, FB-2, DA-IICT, Gandhinagar, Gujarat, I...
# 3  #1206, FB-1, DA-IICT, Gandhinagar, Gujarat, In...
# 4  # 3211, FB-3, DA-IICT, Gandhinagar, Gujarat, I...
#
#                                   email  \
# 0   abhishek_gupta[at]dau[dot]ac[dot]in
# 1  abhishek_jindal[at]dau[dot]ac[dot]in
# 2   abhishek_tilva[at]dau[dot]ac[dot]in
# 3      aditya_tatu[at]dau[dot]ac[dot]in
# 4     ajay_beniwal[at]dau[dot]ac[dot]in
#
#                                       specialization
# 0  Machine Learning, Statistical Signal Processin...
# 1  Reinforcement Learning, Deep Learning for Fina...
# 2  Arbitrage Theory, Stochastic Portfolio Theory,...
# 3  Computer Vision, Image Processing, Pattern Rec...
# 4  Flexible and Printable Electronics for Healthc...

# %%
df.columns = (
    df.columns
    .str.strip()
    .str.lower()
    .str.replace(" ", "_")
)

df.columns
# Out:
# Index(['faculty_type', 'name', 'education', 'phone', 'address', 'email',
#        'specialization'],
#       dtype='object')

# %%
df = df.replace("", pd.NA)

df.isna().sum()
# Out:
# faculty_type       0
# name               0
# education          2
# phone             32
# address           35
# email              1
# specialization     3
# dtype: int64

# %%
def clean_email(email):
    if pd.isna(email):
        return email
    return (
        email.replace("[at]", "@")
             .replace("[dot]", ".")
             .replace(" ", "")
             .lower()
    )

df["email"] = df["email"].apply(clean_email)

# %%
text_cols = [
    "name",
    "education",
    "specialization",
    "area_specialization_short",
    "biography"
]

for col in text_cols:
    if col in df.columns:
        df[col] = df[col].astype(str).str.strip()
        df[col] = df[col].replace("nan", pd.NA)

# %%
df["faculty_type"] = df["faculty_type"].fillna("unknown")

# %%
before = len(df)

df = df.drop_duplicates(
    subset=["name", "faculty_type"],
    keep="first"
)

after = len(df)

print("Duplicates removed:", before - after)
print("Final records:", after)
# Out:
# Duplicates removed: 0
# Final records: 109

# %%
df = df.sort_values(by=["faculty_type", "name"], na_position="last")

# %%
df.to_json(
    "faculty_clean.json",
    orient="records",
    indent=2,
    force_ascii=False
)

print("✅ faculty_clean.json created")
# Out:
# ✅ faculty_clean.json created

# %%
print("Final dataset shape:", df.shape)
df["faculty_type"].value_counts()
# Out:
# Final dataset shape: (109, 7)
# faculty_type
# regular                  67
# adjunct                  26
# international_adjunct    11
# professor_of_practice     4
# distinguished             1
# Name: count, dtype: int64
